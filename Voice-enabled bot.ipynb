# %%
# !pip install portaudio19-dev python-all-dev python3-all-dev
# !pip install portaudio19-dev
# !pip install SpeechRecognition numpy gTTs sklearn 
# !pip install gTTS
# !pip install mpg123
# Out:
# ERROR: Could not find a version that satisfies the requirement portaudio19-dev (from versions: none)
# ERROR: No matching distribution found for portaudio19-dev
# ERROR: Could not find a version that satisfies the requirement portaudio19-dev (from versions: none)
# ERROR: No matching distribution found for portaudio19-dev
# ...

# %%
# !pip install pyglet

# %%
# !pip install pipwin

# %%
# !pipwin install pyaudio
# Out:
# Package `pyaudio` found in cache
# ...
# https://download.lfd.uci.edu/pythonlibs/x6hvwk7i/PyAudio-0.2.11-cp39-cp39-win_amd64.whl
# PyAudio-0.2.11-cp39-cp39-win_amd64.whl
#  Processing c:\users\shrishail\pipwin\pyaudio-0.2.11-cp39-cp39-win_amd64.whl
# PyAudio is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# [*] 111 kB / 111 kB @ 62 kB/s [##################] [100%, 0s left]

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached absl-py-0.8.1.tar.gz (103 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [601 lines of output]
#   Ignoring numpy: markers 'python_version == "3.5" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.5" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.7" and platform_system == "AIX"' don't match your environment
# ...
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# ...
#     Using cached setuptools-62.3.2-py3-none-any.whl (1.2 MB)
# ...

# %%
# !pip install panda

# %%
# !pip install numpy

# %%
# !pip install tensorflow

# %%
# !pip install pyngrok

# %%
# !ngrok authtoken 27K7C6JDBuIV5jIiqDHRSvvrLwd_53BoKugpJzv8fo4zg9exH
# Out:
# ...
#
# Installing ngrok ...
#
# Authtoken saved to configuration file: C:\Users\Shrishail/.ngrok2/ngrok.yml

# %%
import nltk
import datetime
from nltk.stem.porter import PorterStemmer
import numpy as np
import tflearn
import tensorflow as tf
import random
import json
import pickle
import speech_recognition as sr                                                    # importing speech recognition API
import os                                                                          
import speak                                                                       # speak is an instance of gTTS API for bot responses
from gtts import gTTS                                                                 # importing google text-to-speech API
import pyglet                                                                         # importing pyglet for audio playback decoding 
import time, os

stemmer = PorterStemmer()

with open("intents.json") as file:
    data = json.load(file)
with open("data.pickle", "rb") as f:
    words, labels, training, output = pickle.load(f)

def tts(text, lang):                                                                  # defining variable 'text'  and 'lang'
    file = gTTS(text = text, lang = lang)
    filename = 'C:/Users/Shrishail/Desktop/audiofiles/temp.mp3'                       # Store the converted file into a temporary folder 
    file.save(filename)

    music = pyglet.media.load(filename, streaming = False)                            # its decode the saved file and load it 
    music.play()                                                                      # music.play() plays the saved audio

    time.sleep(music.duration)
    os.remove(filename)

# Function to process input
def bag_of_words(s, words):
    bag = [0 for _ in range(len(words))]

    s_words = nltk.word_tokenize(s)
    s_words = [stemmer.stem(word.lower()) for word in s_words]

    for se in s_words:
        for i, w in enumerate(words):
            if w == se:
                bag[i] = 1

    return np.array(bag)


tf.compat.v1.reset_default_graph()

net = tflearn.input_data(shape=[None, len(training[0])])
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, len(output[0]), activation="softmax")
net = tflearn.regression(net)

# Loading existing model from disk
model = tflearn.DNN(net)
model.load("model.tflearn")


def get_bot_response(msg):
    global seat_count
    message = msg
    if message:
        message = message.lower()
        results = model.predict([bag_of_words(message, words)])[0]
        result_index = np.argmax(results)
        tag = labels[result_index]
        if results[result_index] > 0.5:
                for tg in data['intents']:
                    if tg['tag'] == tag:
                        responses = tg['responses']
                response = random.choice(responses)
        else:
            response = "I didn't quite get that, please try again."
        return str(response)
    return "Missing Data!"
print('Dexter:Hi I am Dexter, Who is on the other side?')

reply1 = str('Hi I am Dexter, A University chatbot assistant. I can help you with information on the courses offered by the university, building and classroom locations, student section, facilities offered by our university and how you can enroll.Who is on the other side?')                          # here the string statement is stored in reply1 which will be pass through   
                                                                                   # speak module for speech conversion
lang = 'en-uk'                                                                     # language for the API to reply

tts(reply1, lang)                                                            # text to speech conversion 

r = sr.Recognizer()                                                                # recognizer module from speech recognition (.Recognizer())
while True:

 with sr.Microphone() as source:                                                   # Microphone module from pyaudio (.Microphone())

  r.adjust_for_ambient_noise(source)
 
  audio = r.listen(source)                                                        # recognizing user audio input with r.listen() and storing in audio1
  try:
   name1 = r.recognize_google(audio)                                              # .recognize_google() recognizes the audio with google database and 
   print("Say")                                                                               # convert it to text
   name= input ("you: " + str(name1))                                              # collecting input from recognized audio
   print("Done")   
  except  sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
  except  sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))
     
  print ("Dexter:Hi", name1,"how may I help? ")  
  reply2 = "Hi " + name1 +  " how may I help?"   
  lang = 'en-uk'
  tts(reply2, lang)                                                        # text to speech conversion 
  
  while True:

   with sr.Microphone() as source:

    r.adjust_for_ambient_noise(source)
    audio = r.listen(source)
    try:
     text = r.recognize_google(audio)                                             # speech to text conversion
     print ("Say")
     request = input ("you: " + str(text))
     print("Done")  
    except  sr.UnknownValueError:
     print("Google Speech Recognition could not understand audio")
    except  sr.RequestError as e:
     print("Could not request results from Google Speech Recognition service; {0}".format(e))
      
    reply = str(get_bot_response(text))                                          # bot.get_response() check for the responses from the list trainer and reply back 
    print ("Dexter: ", reply)    
    lang = 'en-uk'
    tts(reply, lang)                                                       # text to speech conversion
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\Shrishail\anaconda3\envs\voice_chatbot\model.tflearn
# INFO:tensorflow:Restoring parameters from C:\Users\Shrishail\anaconda3\envs\voice_chatbot\model.tflearn
# WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Dexter:Hi I am Dexter, Who is on the other side?
# Say
# you: Gopal Iyer
# WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Done
# Dexter:Hi Gopal Iyer how may I help?
# Say
# you: I said f*** off
# Done
# WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Dexter:  I'm Dexter!
# WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Google Speech Recognition could not understand audio
# Dexter:  You can call me Dexter.
# Say
# ...
